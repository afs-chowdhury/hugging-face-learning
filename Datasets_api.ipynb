# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 26.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 61 kB 424 kB/s
# ...
#      |████████████████████████████████| 3.3 MB 44.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 306 kB 22.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 54.3 MB/s
# ...
#      |████████████████████████████████| 243 kB 45.3 MB/s
# ...
#      |████████████████████████████████| 132 kB 65.4 MB/s
# ...
#      |████████████████████████████████| 192 kB 45.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 54.0 MB/s
# ...
#      |████████████████████████████████| 160 kB 61.8 MB/s
# ...

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Out:
# --2021-12-26 06:33:08--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-test.json.gz [following]
# --2021-12-26 06:33:08--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-test.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1051245 (1.0M) [application/octet-stream]
# Saving to: ‘SQuAD_it-test.json.gz’
#
# SQuAD_it-test.json. 100%[===================>]   1.00M  --.-KB/s    in 0.008s
#
# ...

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# Out:
# --2021-12-26 06:43:44--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz [following]
# --2021-12-26 06:43:44--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7725286 (7.4M) [application/octet-stream]
# Saving to: ‘SQuAD_it-train.json.gz’
#
# SQuAD_it-train.json 100%[===================>]   7.37M  --.-KB/s    in 0.03s
#
# ...

# %%
# !gzip -dkv SQuAD_it*.json.gz
# Out:
# SQuAD_it-test.json.gz:	 87.5% -- replaced with SQuAD_it-test.json
# SQuAD_it-train.json.gz:	 82.3% -- replaced with SQuAD_it-train.json

# %%
from datasets import load_dataset
squad_it_dataset = load_dataset("json", data_files = "SQuAD_it-train.json",field = "data")
# Out:
# Using custom data configuration default-bded0c147414aa5f
# Reusing dataset json (/root/.cache/huggingface/datasets/json/default-bded0c147414aa5f/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"]["title"][5]
# Out:
# 'Musica contemporanea per adulti'

# %%
squad_it_dataset["train"]["paragraphs"][5]
# Out:
# [{'context': "La musica contemporanea degli adulti (AC) è uno stile musicale che va dalla musica vocale degli anni Sessanta e Settanta del Novecento al soft rock, alla musica prevalentemente ballad-heavy dei giorni nostri, con vari gradi di ascolto facile, pop, soul, ritmo e blues, tempesta tranquilla e influenza rock. Il contemporaneo adulto è piuttosto una continuazione del facile ascolto e dello stile soft rock che è diventato popolare negli anni Sessanta e Settanta con alcuni aggiustamenti che riflettono l' evoluzione della musica pop/rock.",
#   'qas': [{'answers': [{'answer_start': 365, 'text': 'facile ascolto'}],
#     'id': '56e6b7e56fe0821900b8eb3a',
#     'question': 'Insieme con pop, soul, ritmo e blues, tempesta tranquilla, e rock, quale stile musicale ha influenzato adulti adulti contemporanei?'},
#    {'answers': [{'answer_start': 138, 'text': 'soft rock'}],
#     'id': '56e6b7e56fe0821900b8eb3b',
# ...

# %%
squad_it_dataset["train"][0]
# Out:
# {'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
data_files = {"train":"SQuAD_it-train.json","test":"SQuAD_it-test.json"}
squad_it_datasets = load_dataset("json", data_files = data_files, field = "data")
squad_it_datasets
# Out:
# Using custom data configuration default-7fde2673b4ee9cc5
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-7fde2673b4ee9cc5/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
# also support automatic decomposition
data_files = {"train":"SQuAD_it-train.json.gz","test":"SQuAD_it-test.json.gz"}
squad_it_datasets_dc = load_dataset("json", data_files = data_files, field = "data")
squad_it_datasets_dc
# Out:
# Using custom data configuration default-e728b53853aeaf09
# Reusing dataset json (/root/.cache/huggingface/datasets/json/default-e728b53853aeaf09/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde)
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
# loading from remote server using url
url = "https://github.com/crux82/squad-it/raw/master/"

data_files = {
    "train":url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz"
}

squad_it_dataset_url = load_dataset("json",data_files = data_files , field = "data")
squad_it_dataset_url
# Out:
# Using custom data configuration default-b2375dfabd7ba663
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/7.73M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-b2375dfabd7ba663/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00605/wikivital_mathematics.zip
# Out:
# --2021-12-26 08:22:10--  https://archive.ics.uci.edu/ml/machine-learning-databases/00605/wikivital_mathematics.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1499865 (1.4M) [application/x-httpd-php]
# Saving to: ‘wikivital_mathematics.zip’
#
# wikivital_mathemati 100%[===================>]   1.43M  3.44MB/s    in 0.4s
#
# 2021-12-26 08:22:11 (3.44 MB/s) - ‘wikivital_mathematics.zip’ saved [1499865/1499865]

# %%
# !wget https://raw.githubusercontent.com/banglanlp/bnlp-resources/main/sentiment/ABSA_datasets/BASA_cricket_test.tsv
# !wget https://raw.githubusercontent.com/banglanlp/bnlp-resources/main/sentiment/ABSA_datasets/BASA_cricket_train.tsv
# Out:
# --2021-12-26 08:32:31--  https://raw.githubusercontent.com/banglanlp/bnlp-resources/main/sentiment/ABSA_datasets/BASA_cricket_test.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66936 (65K) [text/plain]
# Saving to: ‘BASA_cricket_test.tsv.1’
#
# BASA_cricket_test.t 100%[===================>]  65.37K  --.-KB/s    in 0.001s
#
# 2021-12-26 08:32:31 (51.4 MB/s) - ‘BASA_cricket_test.tsv.1’ saved [66936/66936]
#
# --2021-12-26 08:32:31--  https://raw.githubusercontent.com/banglanlp/bnlp-resources/main/sentiment/ABSA_datasets/BASA_cricket_train.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %% [markdown]
# # Loading bangla dataset

# %%
from datasets import load_dataset

url = "https://raw.githubusercontent.com/banglanlp/bnlp-resources/main/sentiment/ABSA_datasets/BASA_cricket_"

data_files  = {
    "train" : url +"train.tsv",
    "test" : url +"test.tsv"
}

bangla_cricket_datasets = load_dataset("csv",data_files = data_files , sep ="\t")
# Out:
# Using custom data configuration default-f8b1169f8fffa4b2
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-f8b1169f8fffa4b2/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
bangla_cricket_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'text', 'class_label'],
#         num_rows: 2085
#     })
#     test: Dataset({
#         features: ['id', 'text', 'class_label'],
#         num_rows: 380
#     })
# })

# %%
bangla_cricket_datasets["train"][-1]
# Out:
# {'class_label': 'positive',
#  'id': 908,
#  'text': 'দ্বিতীয় ইনিংসে লিটন দাসের ট্রিপল সেঞ্চুরি চাই'}

# %%
bangla_cricket_datasets["train"][44]
# Out:
# {'class_label': 'negative', 'id': 1806, 'text': 'খুব বেশি না ১৫০ রানে হারবে'}
